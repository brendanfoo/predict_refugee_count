# %% [markdown]
# <a href="https://colab.research.google.com/github/brendanfoo/predict_refugee_count/blob/main/Investigating_large_events.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # imports etc

# %%
# Imports
import pandas as pd
import geopandas as gpd
import random
import altair as alt
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

# Modelling
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from scipy.stats import randint
from sklearn.preprocessing import LabelEncoder

# Tree Visualisation
from sklearn.tree import export_graphviz
from IPython.display import Image
import graphviz

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
fullmerge = pd.read_csv('/content/drive/MyDrive/210RefugeeMoves/datasets/FULLMERGE.csv').iloc[:, 1:]

# %%
fullmerge.columns
# Out:
# Index(['ISO3', 'IDPs from Event', 'econ', 'gov', 'soc', 'cap', 'eco', 'exp',
#        'food', 'hab', 'health', 'infra', 'sens', 'Area', 'Began', 'Ended',
#        'MainCause', 'Severity', 'Duration', 'Magnitude', 'Population',
#        'Population Density (People per Sq. Km.)',
#        'Net international migrants, both sexes', 'Scaled_IDP'],
#       dtype='object')

# %%
gidd = pd.read_csv('/content/drive/MyDrive/210RefugeeMoves/colab/UNHCRdata.csv', encoding='ISO-8859-1')

# %%
base = gidd[['ISO3', 'Date of Event (start)', 'Disaster Internal Displacements (Raw)']]
base = base.groupby(['ISO3', 'Date of Event (start)']).sum().reset_index()
base['Year'] = base['Date of Event (start)'].str[:4].astype(str).astype(int)
base2 = base.rename(columns = {'Disaster Internal Displacements (Raw)': 'IDPs from Event', 'Date of Event (start)': 'Date'})
giddy = base2.copy(deep = True)

# %%
floods = pd.read_csv('/content/drive/MyDrive/210RefugeeMoves/datasets/floods_with_ISO.csv').iloc[:, 1:]

# %% [markdown]
# # events above 3mil

# %%
fullmerge[fullmerge['IDPs from Event'] >= 3000000][['ISO3', 'IDPs from Event', 'Area', 'Began', 'Ended', 'MainCause']]
# Out:
#      ISO3  IDPs from Event   Area       Began       Ended  \
# 463   CHN          3760000 251527  2020-06-15  2020-07-05
# 464   CHN          3760000 154387  2020-06-29  2020-07-03
# 465   CHN          3760000 107563  2020-06-27  2020-07-30
# 1707  PHL          4095280  32477  2013-11-08  2013-11-19
#
#                            MainCause
# 463                   Monsoonal Rain
# 464                  Torrential Rain
# 465   Monsoonal Rain and Dam release
# 1707   Tropical Storm Haiyan/Yolanda

# %% [markdown]
# 1 triplet of year/month pair

# %%
giddy[giddy['IDPs from Event'] >= 3000000][giddy['ISO3'] == 'CHN']
# Out:
# <ipython-input-124-363aa504b473>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   giddy[giddy['IDPs from Event'] >= 3000000][giddy['ISO3'] == 'CHN']
#      ISO3        Date  IDPs from Event  Year
# 1338  CHN  2008-12-05         15000000  2008
# 1339  CHN  2009-01-01          4030507  2009
# 1340  CHN  2010-01-01         15920060  2010
# 1341  CHN  2011-01-01          4489545  2011
# 1342  CHN  2012-01-01          5730800  2012
# 1658  CHN  2020-06-01          3760000  2020

# %%
floods[floods['ISO3'] == 'CHN'][floods['Year Month'] == '2020-06']
# Out:
# <ipython-input-125-5b6ce1a261fd>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   floods[floods['ISO3'] == 'CHN'][floods['Year Month'] == '2020-06']
#      Country   Area       Began       Ended                       MainCause  \
# 1677   China 251527  2020-06-15  2020-07-05                  Monsoonal Rain
# 1685   China 154387  2020-06-29  2020-07-03                 Torrential Rain
# 1686   China 107563  2020-06-27  2020-07-30  Monsoonal Rain and Dam release
#
#       Severity ISO3 Year Month
# 1677         2  CHN    2020-06
# 1685         2  CHN    2020-06
# 1686         2  CHN    2020-06

# %% [markdown]
# #events above 2 mil (below 3 mil)

# %%
fullmerge[fullmerge['IDPs from Event'] >= 2000000][fullmerge['IDPs from Event'] <= 3000000][['ISO3', 'IDPs from Event', 'Area', 'Began', 'Ended', 'MainCause']].sort_values('IDPs from Event')
# Out:
# <ipython-input-126-285343e7d163>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   fullmerge[fullmerge['IDPs from Event'] >= 2000000][fullmerge['IDPs from Event'] <= 3000000][['ISO3', 'IDPs from Event', 'Area', 'Began', 'Ended', 'MainCause']].sort_values('IDPs from Event')
#      ISO3  IDPs from Event   Area       Began       Ended  \
# 1691  PHL          2062402  17181  2009-01-20  2009-01-27
# 1036  IND          2100000  75488  2008-08-05  2008-08-11
# 1037  IND          2100000  80590  2008-08-30  2008-09-08
# 381   CHN          2166500 551385  2017-06-22  2017-07-03
# 1173  IND          2225340 345643  2021-05-25  2021-05-28
# 1174  IND          2225340 331180  2021-05-16  2021-05-23
# 1038  IND          2400000 464318  2008-09-22  2008-09-29
# 1121  IND          2441213 171282  2020-05-19  2020-05-20
# 1122  IND          2441213  37967  2020-05-23  2020-06-03
# 1692  PHL          2499241  10774  2011-01-01  2011-01-18
# 1693  PHL          2499241   3624  2011-01-25  2011-01-31
# 1114  IND          2623349  67023  2019-06-27  2019-07-13
#
#                                 MainCause
# 1691                           Heavy Rain
# 1036                  Heavy monsoon rains
# 1037                        Monsoon Rains
# 381                        Monsoonal Rain
# 1173  Tropical Storm Yaas and Storm Surge
# 1174               Tropical Storm Tauktae
# 1038          Dam release and Heavy  Rain
# 1121                Tropical Storm Amphan
# 1122                Tropical Storm Amphan
# 1692                           Heavy Rain
# 1693                      Torrential Rain
# 1114                       Monsoonal Rain

# %% [markdown]
# 4 pairs of repeat month/years

# %% [markdown]
# # between 1 and 2 mil

# %%
fullmerge[fullmerge['IDPs from Event'] >= 1000000][fullmerge['IDPs from Event'] <= 2000000][['ISO3', 'IDPs from Event', 'Area', 'Began', 'Ended', 'MainCause']].sort_values('IDPs from Event')
# Out:
# <ipython-input-127-13c4eec72da4>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   fullmerge[fullmerge['IDPs from Event'] >= 1000000][fullmerge['IDPs from Event'] <= 2000000][['ISO3', 'IDPs from Event', 'Area', 'Began', 'Ended', 'MainCause']].sort_values('IDPs from Event')
#      ISO3  IDPs from Event   Area       Began       Ended  \
# 1043  IND          1000000 102661  2013-10-12  2013-11-10
# 1042  IND          1000000 246385  2013-10-12  2013-10-14
# 1040  IND          1042271 152700  2013-06-11  2013-06-18
# 1041  IND          1042271  38019  2013-06-23  2013-07-15
# 1039  IND          1042271 131743  2013-06-12  2013-06-27
# 1046  IND          1073673 189576  2014-07-20  2014-07-29
# 150   BGD          1100000  72848  2013-05-14  2013-05-16
# 1075  IND          1200000 629962  2015-07-15  2015-08-19
# 1765  PHL          1250133  84651  2020-10-24  2020-11-02
# 445   CHN          1298000 470032  2019-06-07  2019-06-10
# 1101  IND          1343879  65388  2017-06-02  2017-07-03
# 483   CHN          1430000 129685  2021-07-20  2021-07-29
# 484   CHN          1490000 129685  2021-07-20  2021-07-29
# 1767  PHL          1559917 160744  2020-11-11  2020-11-18
# 1701  PHL          1603844  50412  2013-08-13  2013-08-21
# 1376  MMR          1616761 296424  2015-07-15  2015-08-19
# 280   CHN          1660000 533930  2008-07-28  2008-08-08
# 1083  IND          1670000 167030  2016-07-07  2016-08-03
# 1084  IND          1670000  90614  2016-07-15  2016-09-22
# 1751  PHL          1695229  24395  2019-11-14  2019-11-19
# 1079  IND          1801000  93202  2015-11-10  2015-12-04
# 1110  IND          1821042 123330  2019-05-03  2019-05-07
# 1111  IND          1821042   9468  2019-05-24  2019-05-27
# 1710  PHL          1823176  63967  2014-12-10  2015-01-01
# 1969  USA          1900000    551  2008-01-05  2008-01-09
# 1970  USA          1900000 102263  2008-01-08  2008-01-15
# 163   BGD          1921007  44110  2020-06-30  2020-07-30
# 1175  IND          1948859 239571  2021-06-15  2021-06-21
# 1176  IND          1948859  78068  2021-06-30  2021-07-04
# 1105  IND          1967258 116730  2018-05-29  2018-05-30
# 354   CHN          1990000 720844  2016-06-28  2016-08-03
#
#                                 MainCause
# 1043                           Heavy Rain
# 1042               Tropical Storm Phailin
# 1040                       Monsoonal Rain
# 1041                       Monsoonal Rain
# 1039                       Monsoonal Rain
# 1046                       Monsoonal Rain
# 150                Tropical Storm Mahasen
# 1075  Monsoonal Rain and Tropical Storm K
# 1765                Tropical Storm Molave
# 445                        Monsoonal Rain
# 1101                       Monsoonal Rain
# 483                       Torrential Rain
# 484                       Torrential Rain
# 1767                 Tropical Storm Vamco
# 1701  Monsoonal Rain and Offshore Tropica
# 1376                       Monsoonal Rain
# 280              Tropical Storm Fung-Wong
# 1083                       Monsoonal Rain
# 1084                       Monsoonal Rain
# 1751                 Tropical Storm Ramon
# 1079                 Tropical Storm Rovan
# 1110                Tropical Cyclone Fani
# 1111                           Heavy Rain
# 1710               Tropical Storm Jangmai
# 1969           Dam/Levy, break or release
# 1970                    Rain and snowmelt
# 163                        Monsoonal Rain
# 1175                       Monsoonal Rain
# 1176                       Monsoonal Rain
# 1105                      Torrential Rain
# 354                        Monsoonal Rain

# %% [markdown]
# 5 sets of repeat entries

# %% [markdown]
# # manually merging repeats

# %% [markdown]
# - group by rows with matching values in ISO, Year-Month, and IDPs
# >- for these groups, keep all rows, but reduce IDP values by dividing the value by the amount of repeats (or by area proportion)
#
# Can't combine them all to one row because all aspects of magnitude differ greatly, so each row from flood archive is clearly a different occassion, that presumeably is part of the larger event recorded by GID
#
#
# This seems to be another artifact of flood data in general not being very well recorded, and certainly not in a standardized way. It's hard to analyze flood data when everyone gathers a different incomplete set of information with different definitions of what constitutes a "flood"

# %% [markdown]
# ###testing with only rows over a million

# %%
overmil = fullmerge[fullmerge['IDPs from Event'] >= 1000000][['ISO3', 'IDPs from Event', 'Area', 'Began', 'Ended', 'MainCause']].sort_values('IDPs from Event')
overmil.shape # there are 10 sets of pseudo-duplicates here
# Out:
# (47, 6)

# %%
#pd.options.display.float_format = '{:.0f}'.format

overmil['Began'] = pd.to_datetime(overmil['Began'], errors='coerce')
overmil['Year_Month'] = overmil['Began'].dt.strftime('%Y-%m')

overmil['Total_Group_Area'] = overmil.groupby(['IDPs from Event', 'ISO3', 'Year_Month'])['Area'].transform('sum')
overmil['Scaled_IDP'] = overmil['Area'] * overmil['IDPs from Event'] / overmil['Total_Group_Area']
overmil
# Out:
#      ISO3  IDPs from Event   Area      Began       Ended  \
# 1042  IND          1000000 246385 2013-10-12  2013-10-14
# 1043  IND          1000000 102661 2013-10-12  2013-11-10
# 1040  IND          1042271 152700 2013-06-11  2013-06-18
# 1039  IND          1042271 131743 2013-06-12  2013-06-27
# 1041  IND          1042271  38019 2013-06-23  2013-07-15
# 1046  IND          1073673 189576 2014-07-20  2014-07-29
# 150   BGD          1100000  72848 2013-05-14  2013-05-16
# 1075  IND          1200000 629962 2015-07-15  2015-08-19
# 1765  PHL          1250133  84651 2020-10-24  2020-11-02
# 445   CHN          1298000 470032 2019-06-07  2019-06-10
# 1101  IND          1343879  65388 2017-06-02  2017-07-03
# 483   CHN          1430000 129685 2021-07-20  2021-07-29
# 163                        Monsoonal Rain    2020-06             44110
# 1176                       Monsoonal Rain    2021-06            317639
# 1175                       Monsoonal Rain    2021-06            317639
# 1105                      Torrential Rain    2018-05            116730
# 354                        Monsoonal Rain    2016-06            720844
# 1691                           Heavy Rain    2009-01             17181
# 1037                        Monsoon Rains    2008-08            156078
# 1036                  Heavy monsoon rains    2008-08            156078
# 381                        Monsoonal Rain    2017-06            551385
# 1173  Tropical Storm Yaas and Storm Surge    2021-05            676823
# 1174               Tropical Storm Tauktae    2021-05            676823
# 1038          Dam release and Heavy  Rain    2008-09            464318
# 1122                Tropical Storm Amphan    2020-05            209248
# 1121                Tropical Storm Amphan    2020-05            209248
# 1692                           Heavy Rain    2011-01             14397
# 1693                      Torrential Rain    2011-01             14397
# 1114                       Monsoonal Rain    2019-06             67023
# 463                        Monsoonal Rain    2020-06            513477
# 464                       Torrential Rain    2020-06            513477
# 465        Monsoonal Rain and Dam release    2020-06            513477
# 1707        Tropical Storm Haiyan/Yolanda    2013-11             32477
#
#       Scaled_IDP
# 1042      705881
# 1043      294119
# 1040      493561
# 1039      425823
# 1041      122887
# 1046     1073673
# 150      1100000
# 1075     1200000
# 1765     1250133
# 445      1298000
# 1101     1343879
# 483      1430000
# 484      1490000
# 1767     1559917
# 1701     1603844
# 1376     1616761
# 280      1660000
# 1083     1082659
# 1084      587341
# 1751     1695229
# 1079     1801000
# 1110     1691214
# 1111      129828
# 1710     1823176
# 1970     1889814
# 1969       10186
# 163      1921007
# 1176      478984
# 1175     1469875
# 1105     1967258
# 354      1990000
# 1691     2062402
# 1037     1084327
# 1036     1015673
# 381      2166500
# 1173     1136446
# 1174     1088894
# 1038     2400000
# 1122      442942
# 1121     1998271
# 1692     1870219
# 1693      629022
# 1114     2623349
# 463      1841837
# 464      1130519
# 465       787644
# 1707     4095280

# %% [markdown]
# ###doing it again but with full data

# %%
fullmerge_scaledy = fullmerge.copy(deep=True)[['ISO3', 'IDPs from Event', 'Area', 'Began']]

fullmerge_scaledy['Began'] = pd.to_datetime(fullmerge_scaledy['Began'], errors='coerce')
fullmerge_scaledy['Year_Month'] = fullmerge_scaledy['Began'].dt.strftime('%Y-%m')

fullmerge_scaledy['Total_Group_Area'] = fullmerge_scaledy.groupby(['IDPs from Event', 'ISO3', 'Year_Month'])['Area'].transform('sum')
fullmerge_scaledy['Scaled_IDP'] = fullmerge_scaledy['Area'] * fullmerge_scaledy['IDPs from Event'] / fullmerge_scaledy['Total_Group_Area']

fullmerge['Scaled_IDP'] = np.ceil(fullmerge_scaledy['Scaled_IDP'])
fullmerge[['ISO3', 'IDPs from Event', 'Began', 'Area', 'Scaled_IDP']].sort_values('IDPs from Event')
# Out:
#      ISO3  IDPs from Event       Began   Area  Scaled_IDP
# 2511  USA                1  2019-12-28 138727           1
# 1144  IND                1  2020-06-20  59427           1
# 1143  IND                1  2020-06-02 199451           1
# 650   GRC                1  2016-11-26  36417           1
# 892   IDN                2  2018-12-05 136440           2
# ...   ...              ...         ...    ...         ...
# 1114  IND          2623349  2019-06-27  67023     2623349
# 463   CHN          3760000  2020-06-15 251527     1841837
# 464   CHN          3760000  2020-06-29 154387     1130520
# 465   CHN          3760000  2020-06-27 107563      787645
# 1707  PHL          4095280  2013-11-08  32477     4095280
#
# [2746 rows x 5 columns]
